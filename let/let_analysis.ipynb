# %% [markdown]
# ## IMPORT LIBRARY & REFORAMT DATA

# %%
import os
import pandas as pd
from IPython.display import HTML, display

year = "2025"
month = "T7"
month_number = 7 

# let/data/2025/T2/data.xlsx
# Load the DataFrame
df = pd.read_excel(
    '../let/data/' + year + "/" + month + '/data.xlsx', 
    sheet_name='July 2025',
    usecols=[
    "Response ID",
    "Personal information []",
    "Personal information [].1",
    "Personal information [].2",
    "Personal information [].3",
    "Your English level based on ETOP (if applicable) or self-assessment:",
    "Date of joining Learn English Together"
    ],
)

# Rename columns
df.rename(columns={
    "Response ID": "RESPONSE_ID",
    "Personal information [].1": "PALS_ID",
    "Personal information []": "FULLNAME",   
    "Personal information [].2": "GRADE",
    "Personal information [].3": "SCHOOL",
    "Your English level based on ETOP (if applicable) or self-assessment:": "LEVEL",
    "Date of joining Learn English Together": "DATE_JOINED"
}, inplace=True)


df['PALS_ID'] = df['PALS_ID'].str.upper();

df.sort_values(by=['PALS_ID', 'DATE_JOINED'])
df['FULLNAME'] = df['FULLNAME'].str.upper()
print("TOTAL RECORDS: ", len(df), " RECORDS")
# Display the DataFrame as HTML
HTML(df.head().to_html())
# Out:
# TOTAL RECORDS:  846  RECORDS
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RESPONSE_ID</th>
#       <th>FULLNAME</th>
#       <th>PALS_ID</th>
#       <th>GRADE</th>
#       <th>SCHOOL</th>
#       <th>LEVEL</th>
#       <th>DATE_JOINED</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>56570</td>
#       <td>LÊ THỊ YẾN NHI</td>
#       <td>QB25G0637</td>
#       <td>8</td>
#       <td>THCS Sen Thuỷ</td>
#       <td>Beginner</td>
#       <td>2025-07-08 00:00:00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>56573</td>
#       <td>ĐOÀN QUỐC THỊNH</td>
#       <td>DN25G0550</td>
#       <td>9</td>
#       <td>THCS NGUYỄN THIỆN THUẬT</td>
#       <td>Beginner</td>
#       <td>2025-07-08 00:00:00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>56578</td>
#       <td>VÕ THỊ DIỄM HẰNG</td>
#       <td>QN25G0877</td>
#       <td>8</td>
#       <td>THCS NGUYỄN BỈNH KHIÊM</td>
#       <td>Beginner</td>
#       <td>2025-07-08 00:00:00</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>56580</td>
#       <td>NGUYỄN THANH NHẬT TRƯỜNG</td>
#       <td>HU25P0586</td>
#       <td>9/4</td>
#       <td>THCS Nguyễn Cư Trinh</td>
#       <td>Beginner</td>
#       <td>2025-07-08 00:00:00</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>56582</td>
#       <td>PHAN QUỲNH NHI</td>
#       <td>DN25G0555</td>
#       <td>8.9</td>
#       <td>THCS Nguyễn Huệ</td>
#       <td>Beginner</td>
#       <td>2025-07-08 00:00:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## CHECK DATE_JOINED BE FROM MONDAY TO THURSDAY

# %%
# Convert DATE_JOINED column to datetime format
df['DATE_JOINED'] = pd.to_datetime(df['DATE_JOINED'], errors='coerce')

# Filter rows where DATE_JOINED is not from Monday to Thursday
# 0 - Monday
# 1 - Tuesday
# 2 - Wenesday
# 3 - Thursday
invalid_dates = df[(df['DATE_JOINED'].dt.weekday > 3) | (df['DATE_JOINED'].isna())]

# Display invalid rows
print("INVALID DATE_JOINED (not Monday to Thursday):", len(invalid_dates), "RECORDS")
display(invalid_dates)

# Filter only valid dates (Monday to Thursday)
valid_data = df[df['DATE_JOINED'].dt.weekday <= 3].dropna(subset=['DATE_JOINED'])

# Display the filtered valid data
print("VALID DATE_JOINED (Monday to Thursday):", len(valid_data), "RECORDS")
# HTML(valid_data.head(10).to_html())
# Out:
# INVALID DATE_JOINED (not Monday to Thursday): 10 RECORDS
#      RESPONSE_ID               FULLNAME    PALS_ID GRADE  \
# 102        56731         HOÀNG ANH THƯ   DN23P0485    10
# 104        56737         HOÀNG ANH THƯ   DN23P0485    10
# 303        57019         HOÀNG ANH THƯ   DN23P0485    10
# 306        57028         HOÀNG ANH THƯ   DN23P0485    10
# 316        57042         HOÀNG ANH THƯ   DN23P0485    10
# 327        57066       VÕ THỊ DIỄM HẰNG  QN25G0877     8
# 543        57361   NGUYỄN THỊ MINH THÙY  QT23P0427   11
# 546        57374   NGUYỄN THỊ ÁNH QUYÊN  QN25G0906     8
# 777        57685   NGUYỄN THỊ KIM NGÂN   DT23P0785    12
# 840        57764  NGUYỄN THỊ ÁNH QUYÊN   QN25G0906     8
#
#                      SCHOOL         LEVEL DATE_JOINED
# 102             Thái Phiên       Beginner  2025-07-12
# 104             Thái Phiên       Beginner  2025-07-13
# 303             Thái Phiên       Beginner  2025-07-18
# 306             Thái Phiên       Beginner  2025-07-19
# 316             Thái Phiên       Beginner  2025-07-20
# 327  THCS NGUYỄN BỈNH KHIÊM      Beginner  2025-08-02
# 543          THPT QUẢNG TRỊ  Intermediate  2025-07-06
# 546         Thcs võ thị sáu      Beginner  2025-07-25
# 777        THPT Chu Văn An       Beginner  2025-07-19
# 840        Thcs võ thị sáu       Beginner  2025-07-12
# VALID DATE_JOINED (Monday to Thursday): 836 RECORDS

# %%
# Filter data for year 2025 and month 6 (June)
filtered_data = valid_data[
  (valid_data['DATE_JOINED'].dt.year == 2025) &
  (valid_data['DATE_JOINED'].dt.month == month_number)
]

print(f"RECORDS FOR YEAR 2025, MONTH {month_number}: {len(filtered_data)} RECORDS")
print(f"Date range: {filtered_data['DATE_JOINED'].min()} to {filtered_data['DATE_JOINED'].max()}")

display(filtered_data.head())

# Update valid_data to use the filtered data for subsequent processing
valid_data = filtered_data.copy()
# Out:
# RECORDS FOR YEAR 2025, MONTH 7: 835 RECORDS
# Date range: 2025-07-01 00:00:00 to 2025-07-31 00:00:00
#    RESPONSE_ID                  FULLNAME    PALS_ID GRADE  \
# 0        56570            LÊ THỊ YẾN NHI  QB25G0637     8
# 1        56573           ĐOÀN QUỐC THỊNH  DN25G0550     9
# 2        56578          VÕ THỊ DIỄM HẰNG  QN25G0877     8
# 3        56580  NGUYỄN THANH NHẬT TRƯỜNG  HU25P0586   9/4
# 4        56582            PHAN QUỲNH NHI  DN25G0555   8.9
#
#                     SCHOOL     LEVEL DATE_JOINED
# 0            THCS Sen Thuỷ  Beginner  2025-07-08
# 1  THCS NGUYỄN THIỆN THUẬT  Beginner  2025-07-08
# 2   THCS NGUYỄN BỈNH KHIÊM  Beginner  2025-07-08
# 3     THCS Nguyễn Cư Trinh  Beginner  2025-07-08
# 4          THCS Nguyễn Huệ  Beginner  2025-07-08

# %% [markdown]
# ## CHECK DUPLICATED RECORDS

# %%
# Identify duplicate rows based on DATE_JOINED and PALS_ID
duplicates = valid_data[valid_data.duplicated(subset=['DATE_JOINED', 'PALS_ID'], keep=False)]

# Display duplicate rows
print("DUPLICATED RECORDS: ", len(duplicates), "RECORDS")
display(duplicates)

# Filter out duplicate rows to keep only unique rows based on DATE_JOINED and PALS_ID
unique_data = valid_data.drop_duplicates(subset=['DATE_JOINED', 'PALS_ID'], keep='first')

# Display the unique data
print("VALID RECORDS: ", len(unique_data), "RECORDS")

# EXPORT DATA
unique_data.to_excel('./export/' + year + "/" + month + '/unique_records.xlsx')
print("EXPORT SUCCESSFULLY")
# HTML(unique_data.to_html())
# Out:
# DUPLICATED RECORDS:  39 RECORDS
#      RESPONSE_ID                  FULLNAME     PALS_ID             GRADE  \
# 10         56589          NGUYỄN THỊ HUYỀN   QT25P0489                 8
# 27         56616     PHAN NGUYỄN MINH TÙNG   HU25P0580               9/2
# 52         56659     PHAN NGUYỄN MINH TÙNG   HU25P0580               9/2
# 95         56720     PHAN NGUYỄN MINH TÙNG   HU25P0580               9/2
# 103        56734          LÊ THỊ THÙY DUNG   PY25P0045                 8
# 135        56776          NGUYỄN THỊ HUYỀN   QT25P0489                 8
# 139        56783     PHAN NGUYỄN MINH TÙNG   HU25P0580               9/2
# 150        56800        DƯƠNG HOÀNG BẢO AN   QN25G0909                 8
# 184        56842     PHAN NGUYỄN MINH TÙNG   HU25P0580               9/2
# 196        56855           BÙI PHẠM TRÀ MY   QG23P0652             10A12
# 197        56856           BÙI PHẠM TRÀ MY   QG23P0652             10A12
# 215        56888           NGUYỄN HÀ MY MY   QN25P0863                 8
# 220        56895           NGUYỄN HÀ MY MY   QN25P0863                 8
# 250        56933       VÕ THỊ KHÁNH NGUYÊN   QT24P0474  2025-2026 lớp 10
# 257        56948        DƯƠNG HOÀNG BẢO AN   QN25G0909                 8
# 290        56998     PHAN NGUYỄN MINH TÙNG   HU25P0580               9/2
# 314        57040       HUỲNH THỊ BẢO NGỌC   BD23P0355                 10
# 315        57041       HUỲNH THỊ BẢO NGỌC   BD23P0355                 10
# 317        57046           NGUYỄN DUY PHÁT   BD25P0387                 8
# 318        57050           BÙI PHẠM TRÀ MY   QG23P0652             10A12
# 323        57059              LÂM BẢO NGỌC   QN23P0803                10
# 342        57084        LÊ HUỲNH TRÚC NGÂN   DN25P0546                 8
# 356        57106     PHAN NGUYỄN MINH TÙNG   HU25P0580               9/2
# 426        57196              LÂM BẢO NGỌC   QN23P0803                10
# 541        57359      NGUYỄN THỊ MINH THÙY   QT23P0427               11
# 542        57360      NGUYỄN THỊ MINH THÙY   QT23P0427               11
# 544        57365          LÊ THỊ THÙY DUNG   PY25P0045                 8
# 549        57382          NGUYỄN DUY PHÁT    BD25P0387                 8
# 660        57536        LÊ HUỲNH TRÚC NGÂN   DN25P0546                 8
# 690        57573           BÙI PHẠM TRÀ MY   QG23P0652             10A12
# 701        57587           BÙI PHẠM TRÀ MY   QG23P0652             10A12
# 703        57589           BÙI PHẠM TRÀ MY   QG23P0652             10A12
# 714        57603        TRẦN THỊ BÍCH THẢO   QN25G0905             lớp 8
# 734        57630  NGUYỄN NGỌC QUỲNH HƯƠNG    QB23P0616                10
# 735        57631  NGUYỄN NGỌC QUỲNH HƯƠNG    QB23P0616                10
# 740        57637        TRẦN THỊ BÍCH THẢO   QN25G0905                 8
# 800        57716        NGUYỄN PHƯƠNG THÙY   BD25P0391                 8
# 808        57726        NGUYỄN PHƯƠNG THÙY   BD25P0391                 8
# 831        57751       VÕ THỊ KHÁNH NGUYÊN   QT24P0474  2025-2026 lớp 10
#
#                           SCHOOL         LEVEL DATE_JOINED
# 10             TH&THCS Triệu Sơn  Intermediate  2025-07-08
# 27              THCS Thủy Phương  Intermediate  2025-07-08
# 52              THCS Thủy Phương  Intermediate  2025-07-08
# 95              THCS Thủy Phương  Intermediate  2025-07-08
# 103        THCS NGUYỄN TẤT THÀNH      Beginner  2025-07-10
# 135            TH&THCS Triệu Sơn  Intermediate  2025-07-08
# 139             THCS Thủy Phương  Intermediate  2025-07-08
# 150             Huỳnh thúc kháng      Beginner  2025-07-14
# 184             THCS Thủy Phương  Intermediate  2025-07-08
# 196          THPT Võ Nguyên Giáp  Intermediate  2025-07-15
# 197          THPT Võ Nguyên Giáp  Intermediate  2025-07-14
# 215              THCS Hoàng Diệu      Beginner  2025-07-16
# 220              THCS Hoàng Diệu      Beginner  2025-07-16
# 250       THPT chuyên Lê Quý Đôn      Beginner  2025-07-10
# 257             Huỳnh thúc kháng      Beginner  2025-07-14
# 290             THCS Thủy Phương  Intermediate  2025-07-08
# 314             Thpt Ngô Lê Tân   Intermediate  2025-07-09
# 315             Thpt Ngô Lê Tân   Intermediate  2025-07-09
# 317               THCS Cát Thành  Intermediate  2025-07-21
# 318          THPT Võ Nguyên Giáp  Intermediate  2025-07-21
# 323             THPT Nguyễn Trãi  Intermediate  2025-07-17
# 342                THCS Hoàng Sa      Beginner  2025-07-21
# 356             THCS Thủy Phương  Intermediate  2025-07-08
# 426             THPT Nguyễn Trãi  Intermediate  2025-07-17
# 541               THPT QUẢNG TRỊ  Intermediate  2025-07-03
# 542               THPT QUẢNG TRỊ  Intermediate  2025-07-03
# 544        Thcs Nguyễn Tất Thành      Beginner  2025-07-10
# 549               THCS Cát Thành  Intermediate  2025-07-21
# 660                THCS Hoàng Sa      Beginner  2025-07-21
# 690         THTPT VÕ NGUYÊN GIÁP  Intermediate  2025-07-21
# 701          THPT VÕ NGUYÊN GIÁP  Intermediate  2025-07-14
# 703          THPT VÕ NGUYÊN GIÁP  Intermediate  2025-07-15
# 714               THCS Ngô Quyền      Beginner  2025-07-23
# 734             THPT Lê Quý Đôn   Intermediate  2025-07-21
# 735             THPT Lê Quý Đôn   Intermediate  2025-07-21
# 740               THCS Ngô Quyền      Beginner  2025-07-23
# 800  Trung học cơ sở Phước Thắng      Beginner  2025-07-31
# 808  Trung học cơ sở Phước Thắng      Beginner  2025-07-31
# 831       THPT chuyên Lê Quý Đôn      Beginner  2025-07-10
# VALID RECORDS:  813 RECORDS
# EXPORT SUCCESSFULLY

# %% [markdown]
# ## COMBINE HOURS & EXPORT DATA

# %%
# Chỉ giữ lại 2 cột PALS_ID và FULLNAME
unique_data = unique_data[['PALS_ID', 'FULLNAME']]

# Làm sạch dữ liệu trước khi group by
unique_data['PALS_ID'] = unique_data['PALS_ID'].str.strip().str.upper()
unique_data['FULLNAME'] = unique_data['FULLNAME'].str.strip().str.upper()

# # Sau đó group by lại
total_hours_df = unique_data.groupby(['PALS_ID', 'FULLNAME']).size().reset_index(name='TOTAL_HOURS')


print("TOTAL RECORDS:", len(total_hours_df), " records")
# Out:
# TOTAL RECORDS: 135  records

# %% [markdown]
# ## UNVALID PALS_ID

# %%
# Kiểm tra PALS_ID có hợp lệ theo regex
pattern = r"[A-Z]{2}[0-9]{2}[A-Z]{1}[0-9]{4}"
invalid_pals_id_df = total_hours_df[~total_hours_df['PALS_ID'].str.fullmatch(pattern)]

# In các PALS_ID không hợp lệ
print("Invalid PALS_IDs:", len(invalid_pals_id_df), " records")
display(invalid_pals_id_df)

# Xuất các PALS_ID không hợp lệ ra file Excel
invalid_output_path = './export/'  + year + "/" + month + '/invalid_pals_id_output.xlsx'
invalid_pals_id_df.to_excel(invalid_output_path, index=False)
print(f"Invalid PALS_IDs exported to {invalid_output_path}")
# Out:
# Invalid PALS_IDs: 10  records
#                              PALS_ID               FULLNAME  TOTAL_HOURS
# 0                         0797040225     HOÀNG THỊ XUÂN NHI            1
# 2           BD23P0354 MAI HUỲNH GIAO         MAI HUỲNH GIAO            1
# 14                          BD5P0385        LÒ ĐẶNG MINH KỲ            4
# 22                       DN25G055550        ĐOÀN QUỐC THỊNH            1
# 73                          QN250856   NGUYỄN DƯƠNG GIA BẢO            1
# 78   QN25G0883_NGUYỄN THỊ DIỄM QUỲNH  NGUYỄN THỊ DIỄM QUỲNH            1
# 99                          QN25G900       ĐẶNG LÊ MINH HUY            1
# 108                       QN25P08671     NGUYỄN HUỲNH NHƯ Ý            1
# 115                         QN25P861     LÊ THỊ THẢO NGUYÊN            1
# 134                         QT2G0495            LÊ TIẾN ĐẠT            1
# Invalid PALS_IDs exported to ./export/2025/T7/invalid_pals_id_output.xlsx

# %% [markdown]
# ## FINAL DATA

# %%
# Xuất các hàng hợp lệ với PALS_ID đúng mẫu ra file Excel khác
# Lọc các PALS_ID hợp lệ: phải khớp hoàn toàn với pattern (không có ký tự thừa)
valid_pals_id_df = total_hours_df[total_hours_df['PALS_ID'].str.fullmatch(pattern)]

print("VALID FINAL DATA: ", len(valid_pals_id_df), " records")
display(valid_pals_id_df)

valid_output_path = './export/'  + year + "/" + month + '/valid_pals_id_output.xlsx'
valid_pals_id_df.to_excel(valid_output_path, index=False)
print(f"Valid PALS_IDs exported to {valid_output_path}")
# Out:
# VALID FINAL DATA:  125  records
#        PALS_ID              FULLNAME  TOTAL_HOURS
# 1    BD23P0354        MAI HUỲNH GIAO            8
# 3    BD23P0355    HUỲNH THỊ BẢO NGỌC           17
# 4    BD25G0392          ĐINH CẨM VÂN            3
# 5    BD25P0384          ĐỖ NGỌC TÍNH            8
# 6    BD25P0385       LÒ ĐẶNG MINH KỲ            2
# ..         ...                   ...          ...
# 129  QT25P0488        PHẠM HỒNG PHÚC            1
# 130  QT25P0489      NGUYỄN THỊ HUYỀN            9
# 131  QT25P0490  NGUYỄN NGỌC BẢO TRÂN           14
# 132  QT25P0492    NGUYỄN MAI YẾN NHƯ           13
# 133  QT25P0493       HOÀNG THẢO LINH           10
#
# [125 rows x 3 columns]
# Valid PALS_IDs exported to ./export/2025/T7/valid_pals_id_output.xlsx
